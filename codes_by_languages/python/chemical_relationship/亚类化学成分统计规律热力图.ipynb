# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
font = {
    'family':'SimHei',
    'weight':'bold',
    'size':12
}
matplotlib.rc("font", **font)
import seaborn as sns

# %%
PbBa_NOweathering_class0 = pd.read_csv(".\subclass_dataset\PbBa_NOweathering_class0.csv")#导入八个数据集
PbBa_NOweathering_class1 = pd.read_csv(".\subclass_dataset\PbBa_NOweathering_class1.csv")
PbBa_NOweathering_class2 = pd.read_csv(".\subclass_dataset\PbBa_NOweathering_class2.csv")
PbBa_weathering_class0 = pd.read_csv(".\subclass_dataset\PbBa_weathering_class0.csv")
PbBa_weathering_class1 = pd.read_csv(".\subclass_dataset\PbBa_weathering_class1.csv")
richk_NOweathering_class0 = pd.read_csv(".\subclass_dataset\\richk_NOweathering_class0.csv")
richk_NOweathering_class1 = pd.read_csv(".\subclass_dataset\\richk_NOweathering_class1.csv")
richk_weathering_class0 = pd.read_csv(".\subclass_dataset\\richk_weathering_class0.csv")
richk_weathering_class1 = pd.read_csv(".\subclass_dataset\\richk_weathering_class1.csv")

# %%
dataplot1 = PbBa_NOweathering_class0.iloc[:,1:]
dataplot2 = PbBa_NOweathering_class1.iloc[:,1:]
dataplot3 = PbBa_NOweathering_class2.iloc[:,1:]
dataplot4 = PbBa_weathering_class0.iloc[:,1:]
dataplot5 = PbBa_weathering_class1.iloc[:,1:]
dataplot6 = richk_NOweathering_class0.iloc[:,1:]
dataplot7 = richk_NOweathering_class1.iloc[:,1:]
dataplot8 = richk_weathering_class0.iloc[:,1:]
dataplot9 = richk_weathering_class1.iloc[:,1:]

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot1.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot2.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot3.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot4.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot5.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot6.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot7.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot8.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=[10, 5])#生成热力图,初步观察变量相关情况
sns.heatmap(dataplot9.corr(method='spearman'),cmap="Reds", linewidths=0.5, annot=True)#斯皮尔曼相关(适用于分类数据)
plt.show()
# Out:
# c:\Users\Nucleon\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\Nucleon\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
